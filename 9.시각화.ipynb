# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
import seaborn

# %%
# 한글 폰트가 있는지 검색
import matplotlib.font_manager as fm
for i in fm.fontManager.ttflist:
    if i.name.find('Gulim') != -1:
        print(i.name)
# Out:
# Gulim
# New Gulim

# %%
# 폰트 지정
from matplotlib import rcParams
rcParams['font.family'] = 'Gulim'
rcParams['axes.unicode_minus'] = False

# %%
# 한글 안깨지면 성공!
import matplotlib.pyplot as plt
plt.title('시각화')
plt.xlabel('가로')
plt.ylabel('세로')
# Out:
# Text(0, 0.5, '세로')

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
d1 = anscombe[anscombe['dataset'] == 'I']
d2 = anscombe[anscombe['dataset'] == 'II']
d3 = anscombe[anscombe['dataset'] == 'III']
d4 = anscombe[anscombe['dataset'] == 'IV']

# %%
d1.shape, d2.shape, d3.shape, d4.shape
# Out:
# ((11, 3), (11, 3), (11, 3), (11, 3))

# %%
d1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
d2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
d3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
d4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# describe() 로 보았을때 지표들은 모두 비슷함

# %%
# plot() : 내가 그림을 그릴 객체만들기
plt.plot(d1['x'], d1['y'], 'o')

# %%
plt.plot(d2['x'], d2['y'], 'o')

# %%
plt.plot(d3['x'], d3['y'], 'o')

# %%
plt.plot(d4['x'], d4['y'], 'o')

# %% [markdown]
# 시각화를 하면 전혀 다른 패턴

# %%
dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

# %% [markdown]
# 그림처럼 만들기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(7, 4))  # 도화지 (크기조정)
plt.title('5일간 주식 가격')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid()    # 격자 표시
plt.ylim(95, 110)  # y축 범위
plt.xlim(0, len(dates) - 1)

plt.plot(dates, prices, label='Stock Price', marker='o') # plt.plot(x축, y축)
plt.legend()

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 여러개 그리기
plt.subplot(1, 2, 1)   # 행은 하나, 컬럼은 두개의 첫번째 그림이다  line
plt.plot(dates, prices, marker='o', color='g')
plt.title('Stock Prices - Subplot 1')
plt.xticks(rotation=40)  # x축 글자 기울여주기 (너무 겹쳐서)

plt.subplot(1, 2, 2)   # 행은 하나, 컬럼은 두개의 두번째 그림이다  bar
plt.bar(dates, prices, color='orange')
plt.title('Stock Prices - Subplot 2')
plt.xticks(rotation=40)

plt.savefig('my_stock_price_chart.png')  # 파일로 저장

# %%
import numpy as np
data = np.arange(10)   # 인덱스가 있어서 x, y 축으로 그림 가능!
plt.plot(data)

# %%
# 50개 랜덤한 수 꺼내서 그려보기
data1 = np.random.randint(0, 50, 50)
plt.plot(data1)

# %%
data2 = np.random.randn(50).cumsum()  # 누적
plt.plot(data2)

# %%
plt.hist(np.random.randn(100), bins=20, color='g')
# Out:
# (array([ 2.,  1.,  0.,  5.,  4.,  1.,  5., 12., 19., 10.,  6.,  9.,  9.,
#          5.,  4.,  2.,  3.,  1.,  1.,  1.]),
#  array([-2.30389095, -2.06229932, -1.8207077 , -1.57911608, -1.33752445,
#         -1.09593283, -0.85434121, -0.61274958, -0.37115796, -0.12956634,
#          0.11202528,  0.35361691,  0.59520853,  0.83680015,  1.07839178,
#          1.3199834 ,  1.56157502,  1.80316665,  2.04475827,  2.28634989,
#          2.52794151]),
#  <BarContainer object of 20 artists>)

# %%
# 3개의 구간에 하나씩 넣어주기
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.plot(data)

plt.subplot(1, 3, 2)
plt.plot(data1)

plt.subplot(1, 3, 3)
plt.hist(np.random.randn(100), bins=20, color='g')
# Out:
# (array([ 3.,  4.,  0.,  2.,  2., 10., 11.,  8.,  8., 14., 10.,  8.,  6.,
#          5.,  1.,  3.,  2.,  1.,  0.,  2.]),
#  array([-2.14064066, -1.90211309, -1.66358552, -1.42505795, -1.18653038,
#         -0.94800281, -0.70947524, -0.47094767, -0.2324201 ,  0.00610747,
#          0.24463503,  0.4831626 ,  0.72169017,  0.96021774,  1.19874531,
#          1.43727288,  1.67580045,  1.91432802,  2.15285559,  2.39138315,
#          2.62991072]),
#  <BarContainer object of 20 artists>)

# %%
# scatter plot : 산점도
