# %% [markdown]
# # 과제 1
# Q1.
# [문제1]
# insurance.csv'파일 읽어서 df에 할당하고, 상위 5개 항목 출력하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)

# %%
df = pd.read_csv('data/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# Q2.
# [문제2]
# df의 요약(평균, 4분위수, 전체 갯수 등)정보 확인하기

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# Q3.
# [문제3]
# 신규 컬럼(double bmi)을 생성하고, bmi의 2배가 되는 값을 할당하기

# %%
df['double bmi'] = df['bmi'] * 2
df
# Out:
#       age     sex     bmi  children smoker     region      charges  double bmi
# 0      19  female  27.900         0    yes  southwest  16884.92400       55.80
# 1      18    male  33.770         1     no  southeast   1725.55230       67.54
# 2      28    male  33.000         3     no  southeast   4449.46200       66.00
# 3      33    male  22.705         0     no  northwest  21984.47061       45.41
# 4      32    male  28.880         0     no  northwest   3866.85520       57.76
# ...   ...     ...     ...       ...    ...        ...          ...         ...
# 1333   50    male  30.970         3     no  northwest  10600.54830       61.94
# 1334   18  female  31.920         0     no  northeast   2205.98080       63.84
# 1335   18  female  36.850         0     no  southeast   1629.83350       73.70
# 1336   21  female  25.800         0     no  southwest   2007.94500       51.60
# 1337   61  female  29.070         0    yes  northwest  29141.36030       58.14
#
# [1338 rows x 8 columns]

# %% [markdown]
# Q4.
# [문제4]
# 신규 컬럼(debt)을 생성하고, 0으로 채우기

# %%
df['debt'] = 0
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       double bmi  debt
# 0          55.80     0
# 1          67.54     0
# 2          66.00     0
# 3          45.41     0
# 4          57.76     0
# ...

# %% [markdown]
# Q5.
# [문제5]
# debt에 0부터 값이 증가하도록 채우기

# %%
df['debt'] = [i for i in range(len(df))]
df
# Out:
#       age     sex     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       double bmi  debt
# 0          55.80     0
# 1          67.54     1
# 2          66.00     2
# 3          45.41     3
# 4          57.76     4
# ...

# %% [markdown]
# Q6.
# [문제6]
# 1번 인덱스의 정보 출력

# %%
df.iloc[1]
# Out:
# age                  18
# sex                male
# bmi               33.77
# children              1
# smoker               no
# region        southeast
# charges       1725.5523
# double bmi        67.54
# debt                  1
# Name: 1, dtype: object

# %% [markdown]
# Q7.
# [문제7]
# 'double bmi'열 삭제하기

# %%
df = df.drop(columns='double bmi')
df
# Out:
#       age     sex     bmi  children smoker     region      charges  debt
# 0      19  female  27.900         0    yes  southwest  16884.92400     0
# 1      18    male  33.770         1     no  southeast   1725.55230     1
# 2      28    male  33.000         3     no  southeast   4449.46200     2
# 3      33    male  22.705         0     no  northwest  21984.47061     3
# 4      32    male  28.880         0     no  northwest   3866.85520     4
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   50    male  30.970         3     no  northwest  10600.54830  1333
# 1334   18  female  31.920         0     no  northeast   2205.98080  1334
# 1335   18  female  36.850         0     no  southeast   1629.83350  1335
# 1336   21  female  25.800         0     no  southwest   2007.94500  1336
# 1337   61  female  29.070         0    yes  northwest  29141.36030  1337
#
# [1338 rows x 8 columns]

# %% [markdown]
# Q8.
# [문제8]
# 'age'열, 'sex'열만 출력하기

# %%
df[['age', 'sex']]
# Out:
#       age     sex
# 0      19  female
# 1      18    male
# 2      28    male
# 3      33    male
# 4      32    male
# ...   ...     ...
# 1333   50    male
# 1334   18  female
# 1335   18  female
# 1336   21  female
# 1337   61  female
#
# [1338 rows x 2 columns]

# %% [markdown]
# # 과제2

# %% [markdown]
# Q9.
# [문제9]
# 나이를 1살씩 증가시키기

# %%
df['age'] = df['age'] + 1
df
# Out:
#       age     sex     bmi  children smoker     region      charges  debt
# 0      20  female  27.900         0    yes  southwest  16884.92400     0
# 1      19    male  33.770         1     no  southeast   1725.55230     1
# 2      29    male  33.000         3     no  southeast   4449.46200     2
# 3      34    male  22.705         0     no  northwest  21984.47061     3
# 4      33    male  28.880         0     no  northwest   3866.85520     4
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   51    male  30.970         3     no  northwest  10600.54830  1333
# 1334   19  female  31.920         0     no  northeast   2205.98080  1334
# 1335   19  female  36.850         0     no  southeast   1629.83350  1335
# 1336   22  female  25.800         0     no  southwest   2007.94500  1336
# 1337   62  female  29.070         0    yes  northwest  29141.36030  1337
#
# [1338 rows x 8 columns]

# %% [markdown]
# Q10.
# [문제10]
# charges의 표시형식을 소수점 아래 2자리로 바꾸기

# %%
df['charges'].round(2)
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.94
# 1337    29141.36
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# Q11.
# [문제11]
# 컬럼 정렬(알파벳 순서대로) : age, bmi, charges... 순으로 정렬

# %%
df = df[sorted(df.columns)]
df
# Out:
#       age     bmi      charges  children  debt     region     sex smoker
# 0      20  27.900  16884.92400         0     0  southwest  female    yes
# 1      19  33.770   1725.55230         1     1  southeast    male     no
# 2      29  33.000   4449.46200         3     2  southeast    male     no
# 3      34  22.705  21984.47061         0     3  northwest    male     no
# 4      33  28.880   3866.85520         0     4  northwest    male     no
# ...   ...     ...          ...       ...   ...        ...     ...    ...
# 1333   51  30.970  10600.54830         3  1333  northwest    male     no
# 1334   19  31.920   2205.98080         0  1334  northeast  female     no
# 1335   19  36.850   1629.83350         0  1335  southeast  female     no
# 1336   22  25.800   2007.94500         0  1336  southwest  female     no
# 1337   62  29.070  29141.36030         0  1337  northwest  female    yes
#
# [1338 rows x 8 columns]

# %% [markdown]
# Q12.
# [문제12]
# 값 정렬(age) : 나이 순으로 정렬

# %%
df.sort_values(by='age')
# Out:
#       age     bmi       charges  children  debt     region     sex smoker
# 57     19  31.680  34303.167200         2    57  southeast    male    yes
# 31     19  26.315   2198.189850         0    31  northeast  female     no
# 1023   19  23.320   1711.026800         1  1023  southeast    male     no
# 427    19  29.165   7323.734819         0   427  northeast  female     no
# 1317   19  53.130   1163.462700         0  1317  southeast    male     no
# ...   ...     ...           ...       ...   ...        ...     ...    ...
# 603    65  39.050  16085.127500         3   603  southeast  female     no
# 534    65  40.480  13831.115200         0   534  southeast    male     no
# 1241   65  36.960  49577.662400         2  1241  southeast    male    yes
# 801    65  35.970  14313.846300         0   801  southeast  female     no
# 768    65  39.700  14319.031000         0   768  southwest  female     no
#
# [1338 rows x 8 columns]

# %% [markdown]
# Q13.
# [문제13]
# 나이('age') 평균구하기

# %%
df['age'].mean()
# Out:
# np.float64(40.20702541106129)

# %% [markdown]
# Q14.
# [문제14]
# 보험료('charges')와 가장 상관관계가 높은 변수는?

# %%
df_copy = df.copy()
df_copy['smoker_c'] = df_copy['smoker'].map({'yes': 1, 'no': 0})
df_copy['sex_c'] = df_copy['sex'].map({'male': 1, 'female': 0})

# %%
df_copy
# Out:
#       age     bmi      charges  children  debt     region     sex smoker  \
# 0      20  27.900  16884.92400         0     0  southwest  female    yes
# 1      19  33.770   1725.55230         1     1  southeast    male     no
# 2      29  33.000   4449.46200         3     2  southeast    male     no
# 3      34  22.705  21984.47061         0     3  northwest    male     no
# 4      33  28.880   3866.85520         0     4  northwest    male     no
# ...   ...     ...          ...       ...   ...        ...     ...    ...
# 1333   51  30.970  10600.54830         3  1333  northwest    male     no
# 1334   19  31.920   2205.98080         0  1334  northeast  female     no
# 1335   19  36.850   1629.83350         0  1335  southeast  female     no
# 1336   22  25.800   2007.94500         0  1336  southwest  female     no
# 1337   62  29.070  29141.36030         0  1337  northwest  female    yes
#
#      group_val  smoker_c  sex_c
# 0          흡연자         1      0
# ...

# %%
df_corr = df_copy.corr(numeric_only=True)
df_corr['charges'].sort_values(ascending=False)
# Out:
# charges     1.000000
# smoker_c    0.787251
# age         0.299008
# bmi         0.198341
# children    0.067998
# sex_c       0.057292
# debt       -0.003373
# Name: charges, dtype: float64

# %%
sns.heatmap(df_corr)
# Out:
# <Axes: >

# %% [markdown]
# # 과제 3

# %% [markdown]
# Q15.
# [문제15]
# 남자, 여자가 각각 몇명있는지 구하기

# %%
print(f'남자: {df['sex'].value_counts()['male']}명')
print(f'여자: {df['sex'].value_counts()['female']}명')
# Out:
# 남자: 676명
# 여자: 662명

# %%
print(f'남자: {(df['sex'] == 'male').sum()}명')
print(f'여자: {(df['sex'] == 'female').sum()}명')
# Out:
# 남자: 676명
# 여자: 662명

# %% [markdown]
# Q16.
# [문제16]
# 자녀(children)가 3명인 데이터 출력하기

# %%
df.loc[df['children'] == 3]
# Out:
#       age     bmi      charges  children  debt     region     sex smoker
# 2      29  33.000   4449.46200         3     2  southeast    male     no
# 7      38  27.740   7281.50560         3     7  northwest  female     no
# 25     60  27.720  14001.13380         3    25  southeast  female     no
# 36     63  32.965  15612.19335         3    36  northwest  female     no
# 54     41  28.690   8059.67910         3    54  northwest  female     no
# ...   ...     ...          ...       ...   ...        ...     ...    ...
# 1301   63  30.875  46718.16325         3  1301  northwest    male    yes
# 1314   31  23.655  18765.87545         3  1314  northwest  female    yes
# 1320   32  31.065   5425.02335         3  1320  northwest    male     no
# 1332   53  44.700  11411.68500         3  1332  southwest  female     no
# 1333   51  30.970  10600.54830         3  1333  northwest    male     no
#
# [157 rows x 8 columns]

# %% [markdown]
# Q16.
# [문제16]
# 자녀(children)가 5명 이상인 데이터 출력하기

# %%
df.loc[df['children'] >= 5]
# Out:
#       age     bmi      charges  children  debt     region     sex smoker
# 32     20  28.600   4687.79700         5    32  southwest  female     no
# 71     32  28.500   6799.45800         5    71  northeast    male     no
# 166    21  37.000   4830.63000         5   166  southwest  female     no
# 413    26  23.900   5080.09600         5   413  southwest    male     no
# 425    46  24.310   9788.86590         5   425  southeast    male     no
# 438    53  46.750  12592.53450         5   438  southeast  female     no
# 568    50  31.900  11552.90400         5   568  southwest  female     no
# 640    34  42.400   6666.24300         5   640  southwest    male     no
# 877    34  33.440   6653.78860         5   877  southeast    male     no
# 932    47  25.800  10096.97000         5   932  southwest    male     no
# 937    40  24.225   8965.79575         5   937  northwest  female     no
# 969    40  34.320   8596.82780         5   969  southeast  female     no
# ...

# %% [markdown]
# Q17.
# [문제17]
# bmi가 17 미만인 데이터 출력하기

# %%
df.loc[df['bmi'] < 17]
# Out:
#       age     bmi     charges  children  debt     region     sex smoker
# 172    19  15.960  1694.79640         0   172  northeast    male     no
# 428    22  16.815  3167.45585         1   428  northeast  female     no
# 1226   39  16.815  6640.54485         2  1226  northeast    male     no

# %% [markdown]
# # 과제 4

# %% [markdown]
# Q18.
# [문제18]
# 성별에 따른 보험료 평균

# %%
df.groupby('sex')['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %% [markdown]
# Q19.
# [문제19]
# 흡연여부에 따른 보험료 평균

# %%
df.groupby('smoker')['charges'].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %% [markdown]
# Q20.
# [문제20]
# 지역별 보험료 평균

# %%
df.groupby('region')['charges'].mean()
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %% [markdown]
# Q21.
# [문제21]
# 흡연여부 + 지역별 데이터 평균

# %%
df.groupby(['smoker','region'])['charges'].mean()
# Out:
# smoker  region
# no      northeast     9165.531672
#         northwest     8556.463715
#         southeast     8032.216309
#         southwest     8019.284513
# yes     northeast    29673.536473
#         northwest    30192.003182
#         southeast    34844.996824
#         southwest    32269.063494
# Name: charges, dtype: float64

# %% [markdown]
# Q22.
# [문제22]
# 흡연여부 + 지역별 데이터 평균에서 'charges' 만 츨력하기

# %%
df.groupby(['smoker','region'])['charges'].mean().reset_index(drop=True)
# Out:
# 0     9165.531672
# 1     8556.463715
# 2     8032.216309
# 3     8019.284513
# 4    29673.536473
# 5    30192.003182
# 6    34844.996824
# 7    32269.063494
# Name: charges, dtype: float64

# %% [markdown]
# Q23.
# [문제23]
# 흡연여부 + 지역별 데이터 크기(size)

# %%
df.groupby(['smoker','region'])['charges'].size()
# Out:
# smoker  region
# no      northeast    257
#         northwest    267
#         southeast    273
#         southwest    267
# yes     northeast     67
#         northwest     58
#         southeast     91
#         southwest     58
# Name: charges, dtype: int64

# %% [markdown]
# Q24.
# [문제24]
# smoker 여부에 따라, group_val 컬럼에 '흡연자', '비흡연자' 표시하기

# %%
df
# Out:
#       age     bmi      charges  children  debt     region     sex smoker
# 0      20  27.900  16884.92400         0     0  southwest  female    yes
# 1      19  33.770   1725.55230         1     1  southeast    male     no
# 2      29  33.000   4449.46200         3     2  southeast    male     no
# 3      34  22.705  21984.47061         0     3  northwest    male     no
# 4      33  28.880   3866.85520         0     4  northwest    male     no
# ...   ...     ...          ...       ...   ...        ...     ...    ...
# 1333   51  30.970  10600.54830         3  1333  northwest    male     no
# 1334   19  31.920   2205.98080         0  1334  northeast  female     no
# 1335   19  36.850   1629.83350         0  1335  southeast  female     no
# 1336   22  25.800   2007.94500         0  1336  southwest  female     no
# 1337   62  29.070  29141.36030         0  1337  northwest  female    yes
#
# [1338 rows x 8 columns]

# %%
df = df.copy()
df.loc[df['smoker'] == 'yes', 'group_val'] = '흡연자'
df.loc[df['smoker'] == 'no', 'group_val'] = '비흡연자'
df
# Out:
#       age     bmi      charges  children  debt     region     sex smoker  \
# 0      20  27.900  16884.92400         0     0  southwest  female    yes
# 1      19  33.770   1725.55230         1     1  southeast    male     no
# 2      29  33.000   4449.46200         3     2  southeast    male     no
# 3      34  22.705  21984.47061         0     3  northwest    male     no
# 4      33  28.880   3866.85520         0     4  northwest    male     no
# ...   ...     ...          ...       ...   ...        ...     ...    ...
# 1333   51  30.970  10600.54830         3  1333  northwest    male     no
# 1334   19  31.920   2205.98080         0  1334  northeast  female     no
# 1335   19  36.850   1629.83350         0  1335  southeast  female     no
# 1336   22  25.800   2007.94500         0  1336  southwest  female     no
# 1337   62  29.070  29141.36030         0  1337  northwest  female    yes
#
#      group_val
# 0          흡연자
# 1         비흡연자
# 2         비흡연자
# 3         비흡연자
# ...
